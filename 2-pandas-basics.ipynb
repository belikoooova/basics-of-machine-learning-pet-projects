# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import pandas as pd

# %% [markdown]
# #### Описание данных
#
# В папке Dat (https://github.com/hse-ds/iad-intro-ds/blob/master/2023/homeworks/Data.zip) находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %%
# Разархивируем папку
# !wget https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip
# !unzip /content/Data.zip
# Out:
# --2024-02-04 09:42:01--  https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2023/homeworks/Data.zip [following]
# --2024-02-04 09:42:01--  https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2023/homeworks/Data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16727 (16K) [application/zip]
# Saving to: ‘Data.zip’
#
# Data.zip            100%[===================>]  16.33K  --.-KB/s    in 0s
#
# 2024-02-04 09:42:01 (124 MB/s) - ‘Data.zip’ saved [16727/16727]
#
# ...

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
# Строки-шаблоны для удобного изменения имени файла
info_filename_pattern = "/content/Data/Students_info_{}.csv"
marks_filename_pattern = "/content/Data/Students_marks_{}.csv"
marks_dfs = []
info_dfs = []

# Считаем нужные файлы
for i in range(10):
    info_dfs.append(pd.read_csv(info_filename_pattern.format(i)))
    marks_dfs.append(pd.read_csv(marks_filename_pattern.format(i)))

# Объединим все считанные датасеты в один
info_df = pd.concat(info_dfs, ignore_index=True)
marks_df = pd.concat(marks_dfs, ignore_index=True)

# Объединим (использую left так как считаю информацию о студенте более важной, чем его оценки)
df = pd.merge(info_df, marks_df, on="index", how="left")
df.sample(5)
# Out:
#      index  gender race/ethnicity parental level of education         lunch  \
# 556    556  female        group C          associate's degree      standard
# 110    110  female        group D          associate's degree  free/reduced
# 506    506    male        group A                 high school      standard
# 437    437    male        group D          associate's degree  free/reduced
# 42      42  female        group B          associate's degree      standard
#
#     test preparation course   group  math score  reading score  writing score
# 556               completed  group6          55             72             79
# 110               completed  group2          77             89             98
# 506                    none  group6          68             70             66
# 437                    none  group5          75             66             73
# 42                     none  group1          53             58             65

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
df = df[df.columns.drop("index")]
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course   group  math score  reading score  writing score
# 0                    none  group1          72             72             74
# 1               completed  group1          69             90             88
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
df.describe().loc[["min", "max", "mean", "std"]]
# Можно было бы вывести статистики и по отдельности, но по мне, с describe красивее)
# Out:
#       math score  reading score  writing score
# min      0.00000      17.000000      10.000000
# max    100.00000     100.000000     100.000000
# mean    66.08900      69.169000      68.054000
# std     15.16308      14.600192      15.195657

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
df.isnull().any()
# Для всех столбцов значение false, так что пропущенных нет
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# group                          False
# math score                     False
# reading score                  False
# writing score                  False
# dtype: bool

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
print(f"math: {df['math score'].mean()}")
print(f"reading: {df['reading score'].mean()}")
print(f"writing: {df['writing score'].mean()}")
# Out:
# math: 66.089
# reading: 69.169
# writing: 68.054

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
df.groupby("test preparation course")[["math score", "reading score", "writing score"]].mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
print(df["lunch"].unique())
# Out:
# ['standard' 'free/reduced']

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df = df.rename(columns={"parental level of education": "education", "test preparation course": "test preparation"})
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score
# 0  group1          72             72             74
# 1  group1          69             90             88
# 2  group1          90             95             93
# 3  group1          47             57             44
# 4  group1          76             78             75

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
print(f"Доля студентов, сдавшая экзамен по математике: {(df['math score'] >= passmark).mean()}")

# Сначала отберем тех, кто проходил курс, затем возьмем статистику по математике
second = (df[df['test preparation'] == 'completed']['math score'] >= passmark).mean()
print(f"Доля студентов, проходивших курс подготовки к экзамену и сдавшая экзамен по математике: {second:.3f}")

women = df[df['gender'] == 'female'] # Женщины
women_without_preparing = women[women['test preparation'] == 'none'] # Женщины, не проходившие курс подготовки
third = (women_without_preparing['math score'] < passmark).mean()
print(f"Доля женщин, не проходивших курс подготовки к экзамену и не сдавшая экзамен по математике: {third:.3f}")
# Out:
# Доля студентов, сдавшая экзамен по математике: 0.865
# Доля студентов, проходивших курс подготовки к экзамену и сдавшая экзамен по математике: 0.922
# Доля женщин, не проходивших курс подготовки к экзамену и не сдавшая экзамен по математике: 0.210

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
# %timeit df.groupby('race/ethnicity')['reading score'].mean()

print(df.groupby('race/ethnicity')['reading score'].mean())
# Out:
# 647 µs ± 124 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64

# %%
# %timeit df.groupby('education')['writing score'].min()

print(df.groupby('education')['writing score'].min())
# Out:
# 605 µs ± 8.93 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
# %%timeit
mean_scores = {}

categories = df['race/ethnicity'].unique()

for category in categories:
    mean_score = df[df['race/ethnicity'] == category]['reading score'].mean()
    mean_scores[category] = mean_score
# Out:
# 2.89 ms ± 86.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
min_scores = {}

categories = df['education'].unique()

for category in categories:
    mean_score = df[df['education'] == category]['writing score'].min()
    mean_scores[category] = mean_score
# Out:
# 3.26 ms ± 150 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Циклы работают в 4-5 раз дольше(

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
df.groupby(['gender', 'education']).agg(math_mean=("math score", "mean"), reading_mean=("reading score", "mean"), writing_mean=("writing score", "mean"))
# Out:
#                            math_mean  reading_mean  writing_mean
# gender education
# female associate's degree  65.250000     74.120690     74.000000
#        bachelor's degree   68.349206     77.285714     78.380952
#        high school         59.351064     68.202128     66.691489
#        master's degree     66.500000     76.805556     77.638889
#        some college        65.406780     73.550847     74.050847
#        some high school    59.296703     69.109890     68.285714
# male   associate's degree  70.764151     67.433962     65.405660
#        bachelor's degree   70.581818     68.090909     67.654545
#        high school         64.705882     61.480392     58.539216
#        master's degree     74.826087     73.130435     72.608696
#        some college        69.009259     64.990741     63.148148
#        some high school    67.840909     64.693182     61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
def getExamResult(score):
    return 'F' if score < passmark else 'P'

# %%
df['Math_PassStatus'] = df['math score'].apply(getExamResult)
df['Reading_PassStatus'] = df['reading score'].apply(getExamResult)
df['Writing_PassStatus'] = df['writing score'].apply(getExamResult)

df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score Math_PassStatus  \
# 0  group1          72             72             74               P
# 1  group1          69             90             88               P
# 2  group1          90             95             93               P
# 3  group1          47             57             44               F
# 4  group1          76             78             75               P
#
#   Writing_PassStatus Reading_PassStatus
# 0                  P                  P
# ...

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
def calculate_overall_status(line):
    return 'P' if ((line['Math_PassStatus'] == 'P') and (line['Reading_PassStatus'] == 'P') and (line['Writing_PassStatus'] == 'P')) else 'F'

# %%
df['OverAll_PassStatus'] = df.apply(calculate_overall_status, axis=1)

print(df['OverAll_PassStatus'].value_counts())
# Out:
# P    812
# F    188
# Name: OverAll_PassStatus, dtype: int64

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
def GetGrade(average_mark):
    if (average_mark >= 90):
      return 'A'
    if (80 <= average_mark < 90):
      return 'B'
    if (70 <= average_mark < 80):
      return 'C'
    if (60 <= average_mark < 70):
      return 'D'
    if (50 <= average_mark < 60):
      return 'E'
    else:
      return 'F'

# %%
df['Grade'] = df[['math score', 'reading score', 'writing score']].mean(axis=1).apply(GetGrade)

print(df['Grade'].value_counts())
# Out:
# C    261
# D    256
# E    182
# B    146
# F    103
# A     52
# Name: Grade, dtype: int64

# %% [markdown]
# ![Happy Cat](https://i.pinimg.com/736x/fd/e6/e4/fde6e4949387b9b17e22deb39ae3c7a5.jpg)

# %% [markdown]
# Ура я доделала домашку!!! Надеюсь ассист после проверки будет таким же довольным (а я - после получения оценки...)
